# %%
import pandas as pd

import numpy as np

import random

import csv

# %%
df = pd.read_excel("USstockdata.xlsx")

# %%
#removes rows with empty data and data containing strings and errors

df.dropna()


df = df[df.Returns != "C"]
df = df[df.Returns != "B"]

# %%
# converts data to proper formats, high precision floats and datetime

df["Returns"] = df["Returns"].astype(np.float64)
df["Names Date"] = pd.to_datetime(df["Names Date"])
df.set_index(df["Names Date"])
# df = df.set_index(pd.DatetimeIndex(df["Names Date"]))
# Out:
#             PERMNO Names Date   Returns
# Names Date
# 2007-01-31   10001 2007-01-31  0.023279
# 2007-02-28   10001 2007-02-28  0.261621
# 2007-03-30   10001 2007-03-30  0.019732
# 2007-04-30   10001 2007-04-30  0.002764
# 2007-05-31   10001 2007-05-31  0.043418
# 2007-06-29   10001 2007-06-29  0.000667
# 2007-07-31   10001 2007-07-31 -0.056667
# 2007-08-31   10001 2007-08-31  0.027562
# 2007-09-28   10001 2007-09-28 -0.032325
# 2007-10-31   10001 2007-10-31 -0.040259
# 2007-11-30   10001 2007-11-30  0.079401
# 2007-12-31   10001 2007-12-31 -0.003930
# 2008-01-31   10001 2008-01-31 -0.006082
# 2008-02-29   10001 2008-02-29  0.021704
# 2008-03-31   10001 2008-03-31 -0.052516
# 2008-04-30   10001 2008-04-30 -0.036698
# 2008-05-30   10001 2008-05-30  0.271628
# 2008-06-30   10001 2008-06-30 -0.010092
# 2008-07-31   10001 2008-07-31 -0.053023
# 2008-08-29   10001 2008-08-29 -0.019724
# 2008-09-30   10001 2008-09-30 -0.137374
# 2008-10-31   10001 2008-10-31 -0.018824
# 2008-11-28   10001 2008-11-28 -0.130121
# 2008-12-31   10001 2008-12-31  0.155989
# 2009-01-30   10001 2009-01-30  0.034140
# 2009-02-27   10001 2009-02-27  0.056222
# 2009-03-31   10001 2009-03-31 -0.080537
# 2009-04-30   10001 2009-04-30  0.044621
# 2009-05-29   10001 2009-05-29  0.002941
# 2009-06-30   10001 2009-06-30  0.019446
# ...            ...        ...       ...
# 2013-07-31   93436 2013-07-31  0.250745
# 2013-08-30   93436 2013-08-30  0.258564
# 2013-09-30   93436 2013-09-30  0.144201
# 2013-10-31   93436 2013-10-31 -0.172881
# 2013-11-29   93436 2013-11-29 -0.204202
# 2013-12-31   93436 2013-12-31  0.181875
# 2014-01-31   93436 2014-01-31  0.205951
# 2014-02-28   93436 2014-02-28  0.349485
# 2014-03-31   93436 2014-03-31 -0.148523
# 2014-04-30   93436 2014-04-30 -0.002686
# 2014-05-30   93436 2014-05-30 -0.000577
# 2014-06-30   93436 2014-06-30  0.155412
# 2014-07-31   93436 2014-07-31 -0.069816
# 2014-08-29   93436 2014-08-29  0.207792
# 2014-09-30   93436 2014-09-30 -0.100185
# 2014-10-31   93436 2014-10-31 -0.004038
# 2014-11-28   93436 2014-11-28  0.011667
# 2014-12-31   93436 2014-12-31 -0.090422
# 2015-01-30   93436 2015-01-30 -0.084574
# 2015-02-27   93436 2015-02-27 -0.001277
# 2015-03-31   93436 2015-03-31 -0.071653
# 2015-04-30   93436 2015-04-30  0.197489
# 2015-05-29   93436 2015-05-29  0.109489
# 2015-06-30   93436 2015-06-30  0.069617
# 2015-07-31   93436 2015-07-31 -0.007866
# 2015-08-31   93436 2015-08-31 -0.064212
# 2015-09-30   93436 2015-09-30 -0.002650
# 2015-10-30   93436 2015-10-30 -0.166948
# 2015-11-30   93436 2015-11-30  0.112743
# 2015-12-31   93436 2015-12-31  0.042343
#
# [738092 rows x 3 columns]

# %%
# df.set_index(df["Names Date"])
# df_m = df.groupby(["PERMNO", pd.TimeGrouper(freq='M')])["Returns"].sum()

# %%
def sampling_function(number_in_sample, number_of_repeats):
    """
    Takes a random sample of stocks and calculates average monthly return for a group of them
    Data is stored in a csv file for further analysis
    Args:
    number_in_sample: number of different stocks
    number_of_repeats: times the function was run
    """
    for n in xrange(1, number_of_repeats):
        dfList = df["PERMNO"].tolist()
        rand_smpl = [ dfList[i] for i in sorted(random.sample(xrange(len(dfList)), number_in_sample)) ]
        with open('filename.csv', 'a') as myfile:
            wr = csv.writer(myfile, quoting=csv.QUOTE_ALL)
            wr.writerow(rand_smpl)

        random_sample_df = df[df["PERMNO"].isin(rand_smpl)]
        series_sum_monthly = random_sample_df.groupby( pd.TimeGrouper(freq='M'))["Returns"].sum()
        frame_sum_monthly = series_sum_monthly.to_frame()
        frame_sum_monthly["Ratio"] = frame_sum_monthly.Returns/number_in_sample
        frame_sum_monthly.to_csv('filename.csv',mode = 'a',header ='column_names')
        
    return

# %%
b = sampling_function(10, 10)

# %%
# Out:
# array([(10001, Timestamp('2007-01-31 00:00:00')),
#        (10001, Timestamp('2007-02-28 00:00:00')),
#        (10001, Timestamp('2007-03-31 00:00:00')), ...,
#        (93436, Timestamp('2015-10-31 00:00:00')),
#        (93436, Timestamp('2015-11-30 00:00:00')),
#        (93436, Timestamp('2015-12-31 00:00:00'))], dtype=object)

# %%
ff = df_sum_per_month.to_frame()

# %%
ff.Returns[0]
# Out:
# 151.32491100000007

# %%
frame_sum_monthly.head()
# Out:
#              Returns     Ratio
# 2007-01-31  0.369918  0.018496
# 2007-02-28  0.020534  0.001027
# 2007-03-31  0.663329  0.033166
# 2007-04-30  0.988157  0.049408
# 2007-05-31  1.247615  0.062381

# %%
series_sum_monthly1 = random_sample_df.groupby( pd.TimeGrouper(freq='M'))["Returns"].sum()

# %%
bb = frame_sum_monthly.to_list()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-159-66bec553fbc3> in <module>()
# ----> 1 bb = frame_sum_monthly.to_list()
#
# /home/tric/anaconda2/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    2244                 return self[name]
#    2245             raise AttributeError("'%s' object has no attribute '%s'" %
# -> 2246                                  (type(self).__name__, name))
#    2247
#    2248     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'to_list'

# %%
print bb
# Out:
# {'Returns': {Timestamp('2011-07-31 00:00:00', offset='M'): -0.79892300000000005, Timestamp('2010-12-31 00:00:00', offset='M'): 1.619977, Timestamp('2014-02-28 00:00:00', offset='M'): 0.71558900000000003, Timestamp('2008-02-29 00:00:00', offset='M'): -0.44246200000000013, Timestamp('2014-07-31 00:00:00', offset='M'): -1.4649880000000004, Timestamp('2013-04-30 00:00:00', offset='M'): 0.2615050000000001, Timestamp('2009-02-28 00:00:00', offset='M'): -3.047485, Timestamp('2013-07-31 00:00:00', offset='M'): 1.4097089999999999, Timestamp('2012-08-31 00:00:00', offset='M'): 0.82909600000000006, Timestamp('2008-09-30 00:00:00', offset='M'): -1.796152, Timestamp('2012-04-30 00:00:00', offset='M'): -0.59827700000000006, Timestamp('2009-04-30 00:00:00', offset='M'): 4.3369040000000005, Timestamp('2009-07-31 00:00:00', offset='M'): 1.7646620000000002, Timestamp('2009-11-